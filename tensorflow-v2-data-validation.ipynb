# %% [markdown]
# ## TFDV: Tensorflow Data Validation

# %% [markdown]
# A quickstart guide on using TFDV, showing some of its capabilities. Most of the definition and explanation has been extracted from the official Tensorflow website in order to set the rigth information.

# %% [markdown]
# ## Step 1: Installing and loading the libraries

# %%
# !apt-get install python-dev python-snappy

# %%
# !pip install tensorflow_data_validation

# %%
import pandas as pd
import tensorflow as tf
import tensorflow_data_validation as tfdv

from __future__ import print_function
